# %%
# !apt-get install x11-utils > /dev/null 2>&1
# !pip install pyglet > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl > /dev/null 2>&1

# %%
import gym

# %%
# !apt-get install -y python3-dev zlib1g-dev libjpeg-dev cmake swig
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# python3-dev is already the newest version (3.8.2-0ubuntu2).
# python3-dev set to manually installed.
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-2ubuntu1.5).
# zlib1g-dev set to manually installed.
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 15 not upgraded.
# Need to get 1,086 kB of archives.
# After this operation, 5,413 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig4.0 amd64 4.0.1-5build1 [1,081 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig all 4.0.1-5build1 [5,528 B]
# Fetched 1,086 kB in 1s (1,311 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 126110 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.1-5build1_amd64.deb ...
# Unpacking swig4.0 (4.0.1-5build1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.1-5build1_all.deb ...
# Unpacking swig (4.0.1-5build1) ...
# Setting up swig4.0 (4.0.1-5build1) ...
# Setting up swig (4.0.1-5build1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
pip install gym[box2d]
# Out:
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym[box2d])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d])
#   Using cached pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Collecting swig==4.* (from gym[box2d])
#   Using cached swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2784142 sha256=7ae42f0404f30565ac27758570def0c339b9c132234217b4200a9c4723d9b34a
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: swig, box2d-py, pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.4.0
#     Uninstalling pygame-2.4.0:
#       Successfully uninstalled pygame-2.4.0
# Successfully installed box2d-py-2.3.5 pygame-2.1.0 swig-4.1.1

# %%
env = gym.make("Taxi-v3").env
# Out:
# /usr/local/lib/python3.10/dist-packages/gym/core.py:317: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# /usr/local/lib/python3.10/dist-packages/gym/wrappers/step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
env.reset()
# Out:
# 88

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display as ipythondisplay

# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start()

# %%
# !python -m pip install pygame
# Out:
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (2.1.0)

# %%
from gym import envs
all_envs = envs.registry.all()
env_ids = [env_spec.id for env_spec in all_envs]
print(sorted(env_ids))
# Out:
# ['Acrobot-v1', 'Ant-v2', 'Ant-v3', 'Ant-v4', 'BipedalWalker-v3', 'BipedalWalkerHardcore-v3', 'Blackjack-v1', 'CarRacing-v2', 'CartPole-v0', 'CartPole-v1', 'CliffWalking-v0', 'FrozenLake-v1', 'FrozenLake8x8-v1', 'HalfCheetah-v2', 'HalfCheetah-v3', 'HalfCheetah-v4', 'Hopper-v2', 'Hopper-v3', 'Hopper-v4', 'Humanoid-v2', 'Humanoid-v3', 'Humanoid-v4', 'HumanoidStandup-v2', 'HumanoidStandup-v4', 'InvertedDoublePendulum-v2', 'InvertedDoublePendulum-v4', 'InvertedPendulum-v2', 'InvertedPendulum-v4', 'LunarLander-v2', 'LunarLanderContinuous-v2', 'MountainCar-v0', 'MountainCarContinuous-v0', 'Pendulum-v1', 'Pusher-v2', 'Pusher-v4', 'Reacher-v2', 'Reacher-v4', 'Swimmer-v2', 'Swimmer-v3', 'Swimmer-v4', 'Taxi-v3', 'Walker2d-v2', 'Walker2d-v3', 'Walker2d-v4']
# /usr/local/lib/python3.10/dist-packages/gym/envs/registration.py:421: UserWarning: WARN: The `registry.all` method is deprecated. Please use `registry.values` instead.
#   logger.warn(

# %%
env.reset()
prev_screen = env.render(mode='rgb_array')
plt.imshow(prev_screen)

for i in range(40):
  action = env.action_space.sample()
  obs, reward, done, info = env.step(action)
  screen = env.render(mode='rgb_array')

  plt.imshow(screen)
  ipythondisplay.clear_output(wait=True)
  ipythondisplay.display(plt.gcf())

  if done:
    break

ipythondisplay.clear_output(wait=True)
env.close()

ipythondisplay.clear_output(wait=True)
env.close()

# %%
env.reset()
# Out:
# 94

# %%
print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
state= env.encode(3, 1, 2, 0)
print("State:", state)
env.s = state
# Out:
# Action Space Discrete(6)
# State Space Discrete(500)
# State: 328

# %%
env.P[328]
# Out:
# {0: [(1.0, 428, -1, False)],
#  1: [(1.0, 228, -1, False)],
#  2: [(1.0, 348, -1, False)],
#  3: [(1.0, 328, -1, False)],
#  4: [(1.0, 328, -10, False)],
#  5: [(1.0, 328, -10, False)]}

# %%
env.s = 328
epochs = 0
penalties, rewards = 0, 0
frames = []
done = False
while not done:
  action = env.action_space.sample()
  state, reward, done , info = env.step(action)

  if reward == -10:
     penalties += 1

  frames.append({
      'frame': env.render(mode='ansi'),
      'state': state,
      'action': action,
      'reward': reward
       }
  )

  epochs += 1

  print("Timesteps taken: {}".format(epochs))
  print("Penalties incureed: {}".format(penalties))
# Out:
# Timesteps taken: 1
# Penalties incureed: 1
# Timesteps taken: 2
# Penalties incureed: 2
# Timesteps taken: 3
# Penalties incureed: 2
# Timesteps taken: 4
# Penalties incureed: 2
# Timesteps taken: 5
# Penalties incureed: 2
# Timesteps taken: 6
# Penalties incureed: 2
# Timesteps taken: 7
# Penalties incureed: 2
# Timesteps taken: 8
# Penalties incureed: 2
# Timesteps taken: 9
# Penalties incureed: 2
# Timesteps taken: 10
# Penalties incureed: 2
# Timesteps taken: 11
# Penalties incureed: 2
# Timesteps taken: 12
# Penalties incureed: 3
# Timesteps taken: 13
# Penalties incureed: 4
# Timesteps taken: 14
# Penalties incureed: 4
# Timesteps taken: 15
# Penalties incureed: 5
# Timesteps taken: 16
# Penalties incureed: 5
# Timesteps taken: 17
# Penalties incureed: 5
# Timesteps taken: 18
# Penalties incureed: 5
# Timesteps taken: 19
# Penalties incureed: 6
# Timesteps taken: 20
# Penalties incureed: 7
# Timesteps taken: 21
# Penalties incureed: 8
# Timesteps taken: 22
# Penalties incureed: 8
# Timesteps taken: 23
# Penalties incureed: 8
# Timesteps taken: 24
# Penalties incureed: 8
# Timesteps taken: 25
# Penalties incureed: 8
# Timesteps taken: 26
# Penalties incureed: 9
# Timesteps taken: 27
# Penalties incureed: 9
# Timesteps taken: 28
# Penalties incureed: 10
# Timesteps taken: 29
# Penalties incureed: 11
# Timesteps taken: 30
# Penalties incureed: 12
# Timesteps taken: 31
# Penalties incureed: 12
# Timesteps taken: 32
# Penalties incureed: 12
# Timesteps taken: 33
# Penalties incureed: 13
# Timesteps taken: 34
# Penalties incureed: 13
# Timesteps taken: 35
# Penalties incureed: 13
# Timesteps taken: 36
# Penalties incureed: 14
# Timesteps taken: 37
# Penalties incureed: 15
# Timesteps taken: 38
# Penalties incureed: 15
# Timesteps taken: 39
# Penalties incureed: 15
# Timesteps taken: 40
# Penalties incureed: 15
# Timesteps taken: 41
# Penalties incureed: 15
# Timesteps taken: 42
# Penalties incureed: 16
# Timesteps taken: 43
# Penalties incureed: 17
# Timesteps taken: 44
# Penalties incureed: 17
# Timesteps taken: 45
# Penalties incureed: 17
# Timesteps taken: 46
# Penalties incureed: 18
# Timesteps taken: 47
# Penalties incureed: 18
# Timesteps taken: 48
# Penalties incureed: 18
# Timesteps taken: 49
# Penalties incureed: 18
# Timesteps taken: 50
# Penalties incureed: 19
# Timesteps taken: 51
# Penalties incureed: 19
# Timesteps taken: 52
# Penalties incureed: 20
# Timesteps taken: 53
# Penalties incureed: 21
# Timesteps taken: 54
# Penalties incureed: 21
# Timesteps taken: 55
# Penalties incureed: 21
# Timesteps taken: 56
# Penalties incureed: 22
# Timesteps taken: 57
# Penalties incureed: 23
# Timesteps taken: 58
# Penalties incureed: 23
# Timesteps taken: 59
# Penalties incureed: 23
# Timesteps taken: 60
# Penalties incureed: 23
# Timesteps taken: 61
# Penalties incureed: 24
# Timesteps taken: 62
# Penalties incureed: 24
# Timesteps taken: 63
# Penalties incureed: 25
# Timesteps taken: 64
# Penalties incureed: 26
# Timesteps taken: 65
# Penalties incureed: 27
# Timesteps taken: 66
# Penalties incureed: 27
# Timesteps taken: 67
# Penalties incureed: 27
# Timesteps taken: 68
# Penalties incureed: 27
# Timesteps taken: 69
# Penalties incureed: 28
# Timesteps taken: 70
# Penalties incureed: 28
# Timesteps taken: 71
# Penalties incureed: 28
# Timesteps taken: 72
# Penalties incureed: 28
# Timesteps taken: 73
# Penalties incureed: 29
# Timesteps taken: 74
# Penalties incureed: 30
# Timesteps taken: 75
# Penalties incureed: 31
# Timesteps taken: 76
# Penalties incureed: 31
# Timesteps taken: 77
# Penalties incureed: 31
# Timesteps taken: 78
# Penalties incureed: 31
# Timesteps taken: 79
# Penalties incureed: 31
# Timesteps taken: 80
# Penalties incureed: 31
# Timesteps taken: 81
# Penalties incureed: 32
# Timesteps taken: 82
# Penalties incureed: 33
# Timesteps taken: 83
# Penalties incureed: 33
# Timesteps taken: 84
# Penalties incureed: 34
# Timesteps taken: 85
# Penalties incureed: 35
# Timesteps taken: 86
# Penalties incureed: 36
# Timesteps taken: 87
# Penalties incureed: 36
# Timesteps taken: 88
# Penalties incureed: 37
# Timesteps taken: 89
# Penalties incureed: 38
# Timesteps taken: 90
# Penalties incureed: 38
# Timesteps taken: 91
# Penalties incureed: 38
# Timesteps taken: 92
# Penalties incureed: 39
# Timesteps taken: 93
# Penalties incureed: 39
# Timesteps taken: 94
# Penalties incureed: 40
# Timesteps taken: 95
# Penalties incureed: 40
# Timesteps taken: 96
# Penalties incureed: 40
# Timesteps taken: 97
# Penalties incureed: 40
# Timesteps taken: 98
# Penalties incureed: 41
# Timesteps taken: 99
# Penalties incureed: 41
# Timesteps taken: 100
# Penalties incureed: 41
# Timesteps taken: 101
# Penalties incureed: 41
# Timesteps taken: 102
# Penalties incureed: 41
# Timesteps taken: 103
# Penalties incureed: 41
# Timesteps taken: 104
# Penalties incureed: 41
# Timesteps taken: 105
# Penalties incureed: 41
# Timesteps taken: 106
# Penalties incureed: 41
# Timesteps taken: 107
# Penalties incureed: 42
# Timesteps taken: 108
# Penalties incureed: 43
# Timesteps taken: 109
# Penalties incureed: 43
# Timesteps taken: 110
# Penalties incureed: 44
# Timesteps taken: 111
# Penalties incureed: 45
# Timesteps taken: 112
# Penalties incureed: 45
# Timesteps taken: 113
# Penalties incureed: 46
# Timesteps taken: 114
# Penalties incureed: 47
# Timesteps taken: 115
# Penalties incureed: 48
# Timesteps taken: 116
# Penalties incureed: 48
# Timesteps taken: 117
# Penalties incureed: 48
# Timesteps taken: 118
# Penalties incureed: 49
# Timesteps taken: 119
# Penalties incureed: 50
# Timesteps taken: 120
# Penalties incureed: 50
# Timesteps taken: 121
# Penalties incureed: 50
# Timesteps taken: 122
# Penalties incureed: 50
# Timesteps taken: 123
# Penalties incureed: 51
# Timesteps taken: 124
# Penalties incureed: 52
# Timesteps taken: 125
# Penalties incureed: 53
# Timesteps taken: 126
# Penalties incureed: 54
# Timesteps taken: 127
# Penalties incureed: 54
# Timesteps taken: 128
# Penalties incureed: 54
# Timesteps taken: 129
# Penalties incureed: 54
# Timesteps taken: 130
# Penalties incureed: 54
# Timesteps taken: 131
# Penalties incureed: 54
# Timesteps taken: 132
# Penalties incureed: 54
# Timesteps taken: 133
# Penalties incureed: 54
# Timesteps taken: 134
# Penalties incureed: 54
# Timesteps taken: 135
# Penalties incureed: 54
# Timesteps taken: 136
# Penalties incureed: 55
# Timesteps taken: 137
# Penalties incureed: 55
# Timesteps taken: 138
# Penalties incureed: 55
# Timesteps taken: 139
# Penalties incureed: 55
# Timesteps taken: 140
# Penalties incureed: 55
# Timesteps taken: 141
# Penalties incureed: 55
# Timesteps taken: 142
# Penalties incureed: 55
# Timesteps taken: 143
# Penalties incureed: 55
# Timesteps taken: 144
# Penalties incureed: 55
# Timesteps taken: 145
# Penalties incureed: 55
# Timesteps taken: 146
# Penalties incureed: 55
# Timesteps taken: 147
# Penalties incureed: 56
# Timesteps taken: 148
# Penalties incureed: 56
# Timesteps taken: 149
# Penalties incureed: 56
# Timesteps taken: 150
# Penalties incureed: 57
# Timesteps taken: 151
# Penalties incureed: 58
# Timesteps taken: 152
# Penalties incureed: 58
# Timesteps taken: 153
# Penalties incureed: 58
# Timesteps taken: 154
# Penalties incureed: 59
# Timesteps taken: 155
# Penalties incureed: 59
# Timesteps taken: 156
# Penalties incureed: 60
# Timesteps taken: 157
# Penalties incureed: 60
# Timesteps taken: 158
# Penalties incureed: 61
# Timesteps taken: 159
# Penalties incureed: 61
# Timesteps taken: 160
# Penalties incureed: 62
# Timesteps taken: 161
# Penalties incureed: 62
# Timesteps taken: 162
# Penalties incureed: 63
# Timesteps taken: 163
# Penalties incureed: 63
# Timesteps taken: 164
# Penalties incureed: 64
# Timesteps taken: 165
# Penalties incureed: 64
# Timesteps taken: 166
# Penalties incureed: 65
# Timesteps taken: 167
# Penalties incureed: 66
# Timesteps taken: 168
# Penalties incureed: 67
# Timesteps taken: 169
# Penalties incureed: 68
# Timesteps taken: 170
# Penalties incureed: 69
# Timesteps taken: 171
# Penalties incureed: 69
# Timesteps taken: 172
# Penalties incureed: 69
# Timesteps taken: 173
# Penalties incureed: 69
# Timesteps taken: 174
# Penalties incureed: 70
# Timesteps taken: 175
# Penalties incureed: 70
# Timesteps taken: 176
# Penalties incureed: 71
# Timesteps taken: 177
# Penalties incureed: 71
# Timesteps taken: 178
# Penalties incureed: 71
# Timesteps taken: 179
# Penalties incureed: 72
# Timesteps taken: 180
# Penalties incureed: 72
# Timesteps taken: 181
# Penalties incureed: 72
# Timesteps taken: 182
# Penalties incureed: 72
# Timesteps taken: 183
# Penalties incureed: 73
# Timesteps taken: 184
# Penalties incureed: 73
# Timesteps taken: 185
# Penalties incureed: 73
# Timesteps taken: 186
# Penalties incureed: 73
# Timesteps taken: 187
# Penalties incureed: 74
# Timesteps taken: 188
# Penalties incureed: 74
# Timesteps taken: 189
# Penalties incureed: 74
# Timesteps taken: 190
# Penalties incureed: 74
# Timesteps taken: 191
# Penalties incureed: 74
# Timesteps taken: 192
# Penalties incureed: 74
# Timesteps taken: 193
# Penalties incureed: 74
# Timesteps taken: 194
# Penalties incureed: 74
# Timesteps taken: 195
# Penalties incureed: 74
# Timesteps taken: 196
# Penalties incureed: 75
# Timesteps taken: 197
# Penalties incureed: 75
# Timesteps taken: 198
# Penalties incureed: 75
# Timesteps taken: 199
# Penalties incureed: 75
# Timesteps taken: 200
# Penalties incureed: 76
# Timesteps taken: 201
# Penalties incureed: 76
# Timesteps taken: 202
# Penalties incureed: 77
# Timesteps taken: 203
# Penalties incureed: 77
# Timesteps taken: 204
# Penalties incureed: 77
# Timesteps taken: 205
# Penalties incureed: 77
# Timesteps taken: 206
# Penalties incureed: 78
# Timesteps taken: 207
# Penalties incureed: 78
# Timesteps taken: 208
# Penalties incureed: 78
# Timesteps taken: 209
# Penalties incureed: 79
# Timesteps taken: 210
# Penalties incureed: 79
# Timesteps taken: 211
# Penalties incureed: 79
# Timesteps taken: 212
# Penalties incureed: 79
# Timesteps taken: 213
# Penalties incureed: 80
# Timesteps taken: 214
# Penalties incureed: 81
# Timesteps taken: 215
# Penalties incureed: 82
# Timesteps taken: 216
# Penalties incureed: 82
# Timesteps taken: 217
# Penalties incureed: 82
# Timesteps taken: 218
# Penalties incureed: 83
# Timesteps taken: 219
# Penalties incureed: 83
# Timesteps taken: 220
# Penalties incureed: 84
# Timesteps taken: 221
# Penalties incureed: 84
# Timesteps taken: 222
# Penalties incureed: 84
# Timesteps taken: 223
# Penalties incureed: 85
# Timesteps taken: 224
# Penalties incureed: 86
# Timesteps taken: 225
# Penalties incureed: 86
# Timesteps taken: 226
# Penalties incureed: 86
# Timesteps taken: 227
# Penalties incureed: 86
# Timesteps taken: 228
# Penalties incureed: 87
# Timesteps taken: 229
# Penalties incureed: 87
# Timesteps taken: 230
# Penalties incureed: 88
# Timesteps taken: 231
# Penalties incureed: 89
# Timesteps taken: 232
# Penalties incureed: 89
# Timesteps taken: 233
# Penalties incureed: 90
# Timesteps taken: 234
# Penalties incureed: 90
# Timesteps taken: 235
# Penalties incureed: 91
# Timesteps taken: 236
# Penalties incureed: 92
# Timesteps taken: 237
# Penalties incureed: 92
# Timesteps taken: 238
# Penalties incureed: 92
# Timesteps taken: 239
# Penalties incureed: 93
# Timesteps taken: 240
# Penalties incureed: 93
# Timesteps taken: 241
# Penalties incureed: 93
# Timesteps taken: 242
# Penalties incureed: 93
# Timesteps taken: 243
# Penalties incureed: 94
# Timesteps taken: 244
# Penalties incureed: 95
# Timesteps taken: 245
# Penalties incureed: 95
# Timesteps taken: 246
# Penalties incureed: 95
# Timesteps taken: 247
# Penalties incureed: 96
# Timesteps taken: 248
# Penalties incureed: 96
# Timesteps taken: 249
# Penalties incureed: 97
# Timesteps taken: 250
# Penalties incureed: 97
# Timesteps taken: 251
# Penalties incureed: 98
# Timesteps taken: 252
# Penalties incureed: 99
# Timesteps taken: 253
# Penalties incureed: 99
# Timesteps taken: 254
# Penalties incureed: 100
# Timesteps taken: 255
# Penalties incureed: 100
# Timesteps taken: 256
# Penalties incureed: 100
# Timesteps taken: 257
# Penalties incureed: 101
# Timesteps taken: 258
# Penalties incureed: 101
# Timesteps taken: 259
# Penalties incureed: 102
# Timesteps taken: 260
# Penalties incureed: 102
# Timesteps taken: 261
# Penalties incureed: 103
# Timesteps taken: 262
# Penalties incureed: 103
# Timesteps taken: 263
# Penalties incureed: 103
# Timesteps taken: 264
# Penalties incureed: 104
# Timesteps taken: 265
# Penalties incureed: 104
# Timesteps taken: 266
# Penalties incureed: 104
# Timesteps taken: 267
# Penalties incureed: 105
# Timesteps taken: 268
# Penalties incureed: 105
# Timesteps taken: 269
# Penalties incureed: 106
# Timesteps taken: 270
# Penalties incureed: 106
# Timesteps taken: 271
# Penalties incureed: 107
# Timesteps taken: 272
# Penalties incureed: 108
# Timesteps taken: 273
# Penalties incureed: 108
# Timesteps taken: 274
# Penalties incureed: 109
# Timesteps taken: 275
# Penalties incureed: 110
# Timesteps taken: 276
# Penalties incureed: 110
# Timesteps taken: 277
# Penalties incureed: 110
# Timesteps taken: 278
# Penalties incureed: 110
# Timesteps taken: 279
# Penalties incureed: 110
# Timesteps taken: 280
# Penalties incureed: 111
# Timesteps taken: 281
# Penalties incureed: 112
# Timesteps taken: 282
# Penalties incureed: 112
# Timesteps taken: 283
# Penalties incureed: 112
# Timesteps taken: 284
# Penalties incureed: 113
# Timesteps taken: 285
# Penalties incureed: 113
# Timesteps taken: 286
# Penalties incureed: 113
# Timesteps taken: 287
# Penalties incureed: 114
# Timesteps taken: 288
# Penalties incureed: 114
# Timesteps taken: 289
# Penalties incureed: 114
# Timesteps taken: 290
# Penalties incureed: 114
# Timesteps taken: 291
# Penalties incureed: 114
# Timesteps taken: 292
# Penalties incureed: 114
# Timesteps taken: 293
# Penalties incureed: 114
# Timesteps taken: 294
# Penalties incureed: 115
# Timesteps taken: 295
# Penalties incureed: 115
# Timesteps taken: 296
# Penalties incureed: 116
# Timesteps taken: 297
# Penalties incureed: 117
# Timesteps taken: 298
# Penalties incureed: 118
# Timesteps taken: 299
# Penalties incureed: 119
# Timesteps taken: 300
# Penalties incureed: 119
# Timesteps taken: 301
# Penalties incureed: 119
# Timesteps taken: 302
# Penalties incureed: 120
# Timesteps taken: 303
# Penalties incureed: 121
# Timesteps taken: 304
# Penalties incureed: 122
# Timesteps taken: 305
# Penalties incureed: 122
# Timesteps taken: 306
# Penalties incureed: 123
# Timesteps taken: 307
# Penalties incureed: 123
# Timesteps taken: 308
# Penalties incureed: 123
# Timesteps taken: 309
# Penalties incureed: 124
# Timesteps taken: 310
# Penalties incureed: 124
# Timesteps taken: 311
# Penalties incureed: 124
# Timesteps taken: 312
# Penalties incureed: 124
# Timesteps taken: 313
# Penalties incureed: 124
# Timesteps taken: 314
# Penalties incureed: 124
# Timesteps taken: 315
# Penalties incureed: 124
# Timesteps taken: 316
# Penalties incureed: 124
# Timesteps taken: 317
# Penalties incureed: 125
# Timesteps taken: 318
# Penalties incureed: 126
# Timesteps taken: 319
# Penalties incureed: 127
# Timesteps taken: 320
# Penalties incureed: 127
# Timesteps taken: 321
# Penalties incureed: 128
# Timesteps taken: 322
# Penalties incureed: 129
# Timesteps taken: 323
# Penalties incureed: 130
# Timesteps taken: 324
# Penalties incureed: 131
# Timesteps taken: 325
# Penalties incureed: 131
# Timesteps taken: 326
# Penalties incureed: 131
# Timesteps taken: 327
# Penalties incureed: 131
# Timesteps taken: 328
# Penalties incureed: 132
# Timesteps taken: 329
# Penalties incureed: 132
# Timesteps taken: 330
# Penalties incureed: 133
# Timesteps taken: 331
# Penalties incureed: 134
# Timesteps taken: 332
# Penalties incureed: 134
# Timesteps taken: 333
# Penalties incureed: 134
# Timesteps taken: 334
# Penalties incureed: 134
# Timesteps taken: 335
# Penalties incureed: 134
# Timesteps taken: 336
# Penalties incureed: 135
# Timesteps taken: 337
# Penalties incureed: 135
# Timesteps taken: 338
# Penalties incureed: 135
# Timesteps taken: 339
# Penalties incureed: 135
# Timesteps taken: 340
# Penalties incureed: 135
# Timesteps taken: 341
# Penalties incureed: 135
# Timesteps taken: 342
# Penalties incureed: 135
# Timesteps taken: 343
# Penalties incureed: 135
# Timesteps taken: 344
# Penalties incureed: 135
# Timesteps taken: 345
# Penalties incureed: 135
# Timesteps taken: 346
# Penalties incureed: 136
# Timesteps taken: 347
# Penalties incureed: 137
# Timesteps taken: 348
# Penalties incureed: 138
# Timesteps taken: 349
# Penalties incureed: 139
# Timesteps taken: 350
# Penalties incureed: 139
# Timesteps taken: 351
# Penalties incureed: 140
# Timesteps taken: 352
# Penalties incureed: 140
# Timesteps taken: 353
# Penalties incureed: 140
# Timesteps taken: 354
# Penalties incureed: 140
# Timesteps taken: 355
# Penalties incureed: 140
# Timesteps taken: 356
# Penalties incureed: 140
# Timesteps taken: 357
# Penalties incureed: 141
# Timesteps taken: 358
# Penalties incureed: 142
# Timesteps taken: 359
# Penalties incureed: 142
# Timesteps taken: 360
# Penalties incureed: 143
# Timesteps taken: 361
# Penalties incureed: 143
# Timesteps taken: 362
# Penalties incureed: 143
# Timesteps taken: 363
# Penalties incureed: 144
# Timesteps taken: 364
# Penalties incureed: 144
# Timesteps taken: 365
# Penalties incureed: 145
# Timesteps taken: 366
# Penalties incureed: 146
# Timesteps taken: 367
# Penalties incureed: 146
# Timesteps taken: 368
# Penalties incureed: 147
# Timesteps taken: 369
# Penalties incureed: 147
# Timesteps taken: 370
# Penalties incureed: 147
# Timesteps taken: 371
# Penalties incureed: 148
# Timesteps taken: 372
# Penalties incureed: 149
# Timesteps taken: 373
# Penalties incureed: 149
# Timesteps taken: 374
# Penalties incureed: 149
# Timesteps taken: 375
# Penalties incureed: 150
# Timesteps taken: 376
# Penalties incureed: 150
# Timesteps taken: 377
# Penalties incureed: 151
# Timesteps taken: 378
# Penalties incureed: 152
# Timesteps taken: 379
# Penalties incureed: 153
# Timesteps taken: 380
# Penalties incureed: 153
# Timesteps taken: 381
# Penalties incureed: 153
# Timesteps taken: 382
# Penalties incureed: 154
# Timesteps taken: 383
# Penalties incureed: 155
# Timesteps taken: 384
# Penalties incureed: 155
# Timesteps taken: 385
# Penalties incureed: 155
# Timesteps taken: 386
# Penalties incureed: 155
# Timesteps taken: 387
# Penalties incureed: 155
# Timesteps taken: 388
# Penalties incureed: 155
# Timesteps taken: 389
# Penalties incureed: 155
# Timesteps taken: 390
# Penalties incureed: 155
# Timesteps taken: 391
# Penalties incureed: 155
# Timesteps taken: 392
# Penalties incureed: 155
# Timesteps taken: 393
# Penalties incureed: 155
# Timesteps taken: 394
# Penalties incureed: 155
# Timesteps taken: 395
# Penalties incureed: 156
# Timesteps taken: 396
# Penalties incureed: 157
# Timesteps taken: 397
# Penalties incureed: 157
# Timesteps taken: 398
# Penalties incureed: 157
# Timesteps taken: 399
# Penalties incureed: 157
# Timesteps taken: 400
# Penalties incureed: 157
# Timesteps taken: 401
# Penalties incureed: 157
# Timesteps taken: 402
# Penalties incureed: 157
# Timesteps taken: 403
# Penalties incureed: 158
# Timesteps taken: 404
# Penalties incureed: 159
# Timesteps taken: 405
# Penalties incureed: 160
# Timesteps taken: 406
# Penalties incureed: 161
# Timesteps taken: 407
# Penalties incureed: 161
# Timesteps taken: 408
# Penalties incureed: 162
# Timesteps taken: 409
# Penalties incureed: 162
# Timesteps taken: 410
# Penalties incureed: 162
# Timesteps taken: 411
# Penalties incureed: 162
# Timesteps taken: 412
# Penalties incureed: 162
# Timesteps taken: 413
# Penalties incureed: 162
# Timesteps taken: 414
# Penalties incureed: 162
# Timesteps taken: 415
# Penalties incureed: 162
# Timesteps taken: 416
# Penalties incureed: 163
# Timesteps taken: 417
# Penalties incureed: 163
# Timesteps taken: 418
# Penalties incureed: 164
# Timesteps taken: 419
# Penalties incureed: 165
# Timesteps taken: 420
# Penalties incureed: 165
# Timesteps taken: 421
# Penalties incureed: 166
# Timesteps taken: 422
# Penalties incureed: 166
# Timesteps taken: 423
# Penalties incureed: 167
# Timesteps taken: 424
# Penalties incureed: 167
# Timesteps taken: 425
# Penalties incureed: 167
# Timesteps taken: 426
# Penalties incureed: 167
# Timesteps taken: 427
# Penalties incureed: 168
# Timesteps taken: 428
# Penalties incureed: 168
# Timesteps taken: 429
# Penalties incureed: 168
# Timesteps taken: 430
# Penalties incureed: 168
# Timesteps taken: 431
# Penalties incureed: 168
# Timesteps taken: 432
# Penalties incureed: 168
# Timesteps taken: 433
# Penalties incureed: 168
# Timesteps taken: 434
# Penalties incureed: 169
# Timesteps taken: 435
# Penalties incureed: 169
# Timesteps taken: 436
# Penalties incureed: 170
# Timesteps taken: 437
# Penalties incureed: 170
# Timesteps taken: 438
# Penalties incureed: 170
# Timesteps taken: 439
# Penalties incureed: 171
# Timesteps taken: 440
# Penalties incureed: 171
# Timesteps taken: 441
# Penalties incureed: 172
# Timesteps taken: 442
# Penalties incureed: 172
# Timesteps taken: 443
# Penalties incureed: 173
# Timesteps taken: 444
# Penalties incureed: 173
# Timesteps taken: 445
# Penalties incureed: 174
# Timesteps taken: 446
# Penalties incureed: 174
# Timesteps taken: 447
# Penalties incureed: 174
# Timesteps taken: 448
# Penalties incureed: 174
# Timesteps taken: 449
# Penalties incureed: 175
# Timesteps taken: 450
# Penalties incureed: 175
# Timesteps taken: 451
# Penalties incureed: 175
# Timesteps taken: 452
# Penalties incureed: 175
# Timesteps taken: 453
# Penalties incureed: 175
# Timesteps taken: 454
# Penalties incureed: 175
# Timesteps taken: 455
# Penalties incureed: 176
# Timesteps taken: 456
# Penalties incureed: 176
# Timesteps taken: 457
# Penalties incureed: 176
# Timesteps taken: 458
# Penalties incureed: 177
# Timesteps taken: 459
# Penalties incureed: 178
# Timesteps taken: 460
# Penalties incureed: 178
# Timesteps taken: 461
# Penalties incureed: 178
# Timesteps taken: 462
# Penalties incureed: 178
# Timesteps taken: 463
# Penalties incureed: 178
# Timesteps taken: 464
# Penalties incureed: 178
# Timesteps taken: 465
# Penalties incureed: 178
# Timesteps taken: 466
# Penalties incureed: 178
# Timesteps taken: 467
# Penalties incureed: 178
# Timesteps taken: 468
# Penalties incureed: 179
# Timesteps taken: 469
# Penalties incureed: 179
# Timesteps taken: 470
# Penalties incureed: 180
# Timesteps taken: 471
# Penalties incureed: 181
# Timesteps taken: 472
# Penalties incureed: 181
# Timesteps taken: 473
# Penalties incureed: 181
# Timesteps taken: 474
# Penalties incureed: 182
# Timesteps taken: 475
# Penalties incureed: 183
# Timesteps taken: 476
# Penalties incureed: 183
# Timesteps taken: 477
# Penalties incureed: 183
# Timesteps taken: 478
# Penalties incureed: 184
# Timesteps taken: 479
# Penalties incureed: 184
# Timesteps taken: 480
# Penalties incureed: 184
# Timesteps taken: 481
# Penalties incureed: 184
# Timesteps taken: 482
# Penalties incureed: 184
# Timesteps taken: 483
# Penalties incureed: 185
# Timesteps taken: 484
# Penalties incureed: 185
# Timesteps taken: 485
# Penalties incureed: 185
# Timesteps taken: 486
# Penalties incureed: 185
# Timesteps taken: 487
# Penalties incureed: 185
# Timesteps taken: 488
# Penalties incureed: 185
# Timesteps taken: 489
# Penalties incureed: 186
# Timesteps taken: 490
# Penalties incureed: 186
# Timesteps taken: 491
# Penalties incureed: 186
# Timesteps taken: 492
# Penalties incureed: 186
# Timesteps taken: 493
# Penalties incureed: 186
# Timesteps taken: 494
# Penalties incureed: 187
# Timesteps taken: 495
# Penalties incureed: 188
# Timesteps taken: 496
# Penalties incureed: 188
# Timesteps taken: 497
# Penalties incureed: 188
# Timesteps taken: 498
# Penalties incureed: 188
# Timesteps taken: 499
# Penalties incureed: 188
# Timesteps taken: 500
# Penalties incureed: 189
# Timesteps taken: 501
# Penalties incureed: 189
# Timesteps taken: 502
# Penalties incureed: 189
# Timesteps taken: 503
# Penalties incureed: 189
# Timesteps taken: 504
# Penalties incureed: 190
# Timesteps taken: 505
# Penalties incureed: 190
# Timesteps taken: 506
# Penalties incureed: 190
# Timesteps taken: 507
# Penalties incureed: 190
# Timesteps taken: 508
# Penalties incureed: 190
# Timesteps taken: 509
# Penalties incureed: 190
# Timesteps taken: 510
# Penalties incureed: 190
# Timesteps taken: 511
# Penalties incureed: 190
# Timesteps taken: 512
# Penalties incureed: 190
# Timesteps taken: 513
# Penalties incureed: 190
# Timesteps taken: 514
# Penalties incureed: 190
# Timesteps taken: 515
# Penalties incureed: 190
# Timesteps taken: 516
# Penalties incureed: 190
# Timesteps taken: 517
# Penalties incureed: 191
# Timesteps taken: 518
# Penalties incureed: 191
# Timesteps taken: 519
# Penalties incureed: 191
# Timesteps taken: 520
# Penalties incureed: 192
# Timesteps taken: 521
# Penalties incureed: 192
# Timesteps taken: 522
# Penalties incureed: 192
# Timesteps taken: 523
# Penalties incureed: 192
# Timesteps taken: 524
# Penalties incureed: 193
# Timesteps taken: 525
# Penalties incureed: 193
# Timesteps taken: 526
# Penalties incureed: 193
# Timesteps taken: 527
# Penalties incureed: 193
# Timesteps taken: 528
# Penalties incureed: 194
# Timesteps taken: 529
# Penalties incureed: 194
# Timesteps taken: 530
# Penalties incureed: 195
# Timesteps taken: 531
# Penalties incureed: 196
# Timesteps taken: 532
# Penalties incureed: 197
# Timesteps taken: 533
# Penalties incureed: 198
# Timesteps taken: 534
# Penalties incureed: 199
# Timesteps taken: 535
# Penalties incureed: 199
# Timesteps taken: 536
# Penalties incureed: 199
# Timesteps taken: 537
# Penalties incureed: 199
# Timesteps taken: 538
# Penalties incureed: 200
# Timesteps taken: 539
# Penalties incureed: 200
# Timesteps taken: 540
# Penalties incureed: 201
# Timesteps taken: 541
# Penalties incureed: 202
# Timesteps taken: 542
# Penalties incureed: 202
# Timesteps taken: 543
# Penalties incureed: 202
# Timesteps taken: 544
# Penalties incureed: 202
# Timesteps taken: 545
# Penalties incureed: 203
# Timesteps taken: 546
# Penalties incureed: 203
# Timesteps taken: 547
# Penalties incureed: 203
# Timesteps taken: 548
# Penalties incureed: 204
# Timesteps taken: 549
# Penalties incureed: 204
# Timesteps taken: 550
# Penalties incureed: 204
# Timesteps taken: 551
# Penalties incureed: 204
# Timesteps taken: 552
# Penalties incureed: 204
# Timesteps taken: 553
# Penalties incureed: 205
# Timesteps taken: 554
# Penalties incureed: 206
# Timesteps taken: 555
# Penalties incureed: 207
# Timesteps taken: 556
# Penalties incureed: 207
# Timesteps taken: 557
# Penalties incureed: 208
# Timesteps taken: 558
# Penalties incureed: 209
# Timesteps taken: 559
# Penalties incureed: 209
# Timesteps taken: 560
# Penalties incureed: 210
# Timesteps taken: 561
# Penalties incureed: 210
# Timesteps taken: 562
# Penalties incureed: 210
# Timesteps taken: 563
# Penalties incureed: 211
# Timesteps taken: 564
# Penalties incureed: 211
# Timesteps taken: 565
# Penalties incureed: 211
# Timesteps taken: 566
# Penalties incureed: 212
# Timesteps taken: 567
# Penalties incureed: 212
# Timesteps taken: 568
# Penalties incureed: 212
# Timesteps taken: 569
# Penalties incureed: 212
# Timesteps taken: 570
# Penalties incureed: 212
# Timesteps taken: 571
# Penalties incureed: 212
# Timesteps taken: 572
# Penalties incureed: 212
# Timesteps taken: 573
# Penalties incureed: 213
# Timesteps taken: 574
# Penalties incureed: 213
# Timesteps taken: 575
# Penalties incureed: 213
# Timesteps taken: 576
# Penalties incureed: 213
# Timesteps taken: 577
# Penalties incureed: 213
# Timesteps taken: 578
# Penalties incureed: 213
# Timesteps taken: 579
# Penalties incureed: 213
# Timesteps taken: 580
# Penalties incureed: 214
# Timesteps taken: 581
# Penalties incureed: 215
# Timesteps taken: 582
# Penalties incureed: 216
# Timesteps taken: 583
# Penalties incureed: 216
# Timesteps taken: 584
# Penalties incureed: 217
# Timesteps taken: 585
# Penalties incureed: 218
# Timesteps taken: 586
# Penalties incureed: 219
# Timesteps taken: 587
# Penalties incureed: 219
# Timesteps taken: 588
# Penalties incureed: 220
# Timesteps taken: 589
# Penalties incureed: 220
# Timesteps taken: 590
# Penalties incureed: 220
# Timesteps taken: 591
# Penalties incureed: 220
# Timesteps taken: 592
# Penalties incureed: 220
# Timesteps taken: 593
# Penalties incureed: 220
# Timesteps taken: 594
# Penalties incureed: 220
# Timesteps taken: 595
# Penalties incureed: 221
# Timesteps taken: 596
# Penalties incureed: 221
# Timesteps taken: 597
# Penalties incureed: 221
# Timesteps taken: 598
# Penalties incureed: 222
# Timesteps taken: 599
# Penalties incureed: 223
# Timesteps taken: 600
# Penalties incureed: 223
# Timesteps taken: 601
# Penalties incureed: 224
# Timesteps taken: 602
# Penalties incureed: 224
# Timesteps taken: 603
# Penalties incureed: 224
# Timesteps taken: 604
# Penalties incureed: 224
# Timesteps taken: 605
# Penalties incureed: 224
# Timesteps taken: 606
# Penalties incureed: 224
# Timesteps taken: 607
# Penalties incureed: 224
# Timesteps taken: 608
# Penalties incureed: 225
# Timesteps taken: 609
# Penalties incureed: 226
# Timesteps taken: 610
# Penalties incureed: 227
# Timesteps taken: 611
# Penalties incureed: 227
# Timesteps taken: 612
# Penalties incureed: 227
# Timesteps taken: 613
# Penalties incureed: 228
# Timesteps taken: 614
# Penalties incureed: 228
# Timesteps taken: 615
# Penalties incureed: 229
# Timesteps taken: 616
# Penalties incureed: 230
# Timesteps taken: 617
# Penalties incureed: 230
# Timesteps taken: 618
# Penalties incureed: 230
# Timesteps taken: 619
# Penalties incureed: 230
# Timesteps taken: 620
# Penalties incureed: 231
# Timesteps taken: 621
# Penalties incureed: 232
# Timesteps taken: 622
# Penalties incureed: 232
# Timesteps taken: 623
# Penalties incureed: 232
# Timesteps taken: 624
# Penalties incureed: 232
# Timesteps taken: 625
# Penalties incureed: 232
# Timesteps taken: 626
# Penalties incureed: 232
# Timesteps taken: 627
# Penalties incureed: 232
# Timesteps taken: 628
# Penalties incureed: 232
# Timesteps taken: 629
# Penalties incureed: 232
# Timesteps taken: 630
# Penalties incureed: 233
# Timesteps taken: 631
# Penalties incureed: 234
# Timesteps taken: 632
# Penalties incureed: 234
# Timesteps taken: 633
# Penalties incureed: 235
# Timesteps taken: 634
# Penalties incureed: 236
# Timesteps taken: 635
# Penalties incureed: 237
# Timesteps taken: 636
# Penalties incureed: 237
# Timesteps taken: 637
# Penalties incureed: 237
# Timesteps taken: 638
# Penalties incureed: 237
# Timesteps taken: 639
# Penalties incureed: 238
# Timesteps taken: 640
# Penalties incureed: 238
# Timesteps taken: 641
# Penalties incureed: 238
# Timesteps taken: 642
# Penalties incureed: 238
# Timesteps taken: 643
# Penalties incureed: 238
# Timesteps taken: 644
# Penalties incureed: 238
# Timesteps taken: 645
# Penalties incureed: 239
# Timesteps taken: 646
# Penalties incureed: 239
# Timesteps taken: 647
# Penalties incureed: 239
# Timesteps taken: 648
# Penalties incureed: 239
# Timesteps taken: 649
# Penalties incureed: 239
# Timesteps taken: 650
# Penalties incureed: 239
# Timesteps taken: 651
# Penalties incureed: 240
# Timesteps taken: 652
# Penalties incureed: 240
# Timesteps taken: 653
# Penalties incureed: 240
# Timesteps taken: 654
# Penalties incureed: 240
# Timesteps taken: 655
# Penalties incureed: 240
# Timesteps taken: 656
# Penalties incureed: 241
# Timesteps taken: 657
# Penalties incureed: 241
# Timesteps taken: 658
# Penalties incureed: 241
# Timesteps taken: 659
# Penalties incureed: 242
# Timesteps taken: 660
# Penalties incureed: 242
# Timesteps taken: 661
# Penalties incureed: 242
# Timesteps taken: 662
# Penalties incureed: 242
# Timesteps taken: 663
# Penalties incureed: 242
# Timesteps taken: 664
# Penalties incureed: 243
# Timesteps taken: 665
# Penalties incureed: 243
# Timesteps taken: 666
# Penalties incureed: 244
# Timesteps taken: 667
# Penalties incureed: 245
# Timesteps taken: 668
# Penalties incureed: 246
# Timesteps taken: 669
# Penalties incureed: 246
# Timesteps taken: 670
# Penalties incureed: 246
# Timesteps taken: 671
# Penalties incureed: 246
# Timesteps taken: 672
# Penalties incureed: 246
# Timesteps taken: 673
# Penalties incureed: 246
# Timesteps taken: 674
# Penalties incureed: 246
# Timesteps taken: 675
# Penalties incureed: 246
# Timesteps taken: 676
# Penalties incureed: 246
# Timesteps taken: 677
# Penalties incureed: 247
# Timesteps taken: 678
# Penalties incureed: 247
# Timesteps taken: 679
# Penalties incureed: 247
# Timesteps taken: 680
# Penalties incureed: 247
# Timesteps taken: 681
# Penalties incureed: 248
# Timesteps taken: 682
# Penalties incureed: 248
# Timesteps taken: 683
# Penalties incureed: 248
# Timesteps taken: 684
# Penalties incureed: 248
# Timesteps taken: 685
# Penalties incureed: 248
# Timesteps taken: 686
# Penalties incureed: 249
# Timesteps taken: 687
# Penalties incureed: 249
# Timesteps taken: 688
# Penalties incureed: 249
# Timesteps taken: 689
# Penalties incureed: 249
# Timesteps taken: 690
# Penalties incureed: 250
# Timesteps taken: 691
# Penalties incureed: 250
# Timesteps taken: 692
# Penalties incureed: 250
# Timesteps taken: 693
# Penalties incureed: 250
# Timesteps taken: 694
# Penalties incureed: 250
# Timesteps taken: 695
# Penalties incureed: 250
# Timesteps taken: 696
# Penalties incureed: 251
# Timesteps taken: 697
# Penalties incureed: 252
# Timesteps taken: 698
# Penalties incureed: 253
# Timesteps taken: 699
# Penalties incureed: 253
# Timesteps taken: 700
# Penalties incureed: 254
# Timesteps taken: 701
# Penalties incureed: 255
# Timesteps taken: 702
# Penalties incureed: 255
# Timesteps taken: 703
# Penalties incureed: 256
# Timesteps taken: 704
# Penalties incureed: 257
# Timesteps taken: 705
# Penalties incureed: 257
# Timesteps taken: 706
# Penalties incureed: 257
# Timesteps taken: 707
# Penalties incureed: 257
# Timesteps taken: 708
# Penalties incureed: 257
# Timesteps taken: 709
# Penalties incureed: 257
# Timesteps taken: 710
# Penalties incureed: 258
# Timesteps taken: 711
# Penalties incureed: 258
# Timesteps taken: 712
# Penalties incureed: 259
# Timesteps taken: 713
# Penalties incureed: 259
# Timesteps taken: 714
# Penalties incureed: 260
# Timesteps taken: 715
# Penalties incureed: 260
# Timesteps taken: 716
# Penalties incureed: 260
# Timesteps taken: 717
# Penalties incureed: 261
# Timesteps taken: 718
# Penalties incureed: 262
# Timesteps taken: 719
# Penalties incureed: 262
# Timesteps taken: 720
# Penalties incureed: 262
# Timesteps taken: 721
# Penalties incureed: 262
# Timesteps taken: 722
# Penalties incureed: 262
# Timesteps taken: 723
# Penalties incureed: 262
# Timesteps taken: 724
# Penalties incureed: 262
# Timesteps taken: 725
# Penalties incureed: 262
# Timesteps taken: 726
# Penalties incureed: 262
# Timesteps taken: 727
# Penalties incureed: 263
# Timesteps taken: 728
# Penalties incureed: 264
# Timesteps taken: 729
# Penalties incureed: 264
# Timesteps taken: 730
# Penalties incureed: 264
# Timesteps taken: 731
# Penalties incureed: 264
# Timesteps taken: 732
# Penalties incureed: 264
# Timesteps taken: 733
# Penalties incureed: 265
# Timesteps taken: 734
# Penalties incureed: 265
# Timesteps taken: 735
# Penalties incureed: 265
# Timesteps taken: 736
# Penalties incureed: 265
# Timesteps taken: 737
# Penalties incureed: 265
# Timesteps taken: 738
# Penalties incureed: 266
# Timesteps taken: 739
# Penalties incureed: 266
# Timesteps taken: 740
# Penalties incureed: 267
# Timesteps taken: 741
# Penalties incureed: 268
# Timesteps taken: 742
# Penalties incureed: 269
# Timesteps taken: 743
# Penalties incureed: 269
# Timesteps taken: 744
# Penalties incureed: 269
# Timesteps taken: 745
# Penalties incureed: 270
# Timesteps taken: 746
# Penalties incureed: 270
# Timesteps taken: 747
# Penalties incureed: 270
# Timesteps taken: 748
# Penalties incureed: 271
# Timesteps taken: 749
# Penalties incureed: 271
# Timesteps taken: 750
# Penalties incureed: 271
# Timesteps taken: 751
# Penalties incureed: 271
# Timesteps taken: 752
# Penalties incureed: 271
# Timesteps taken: 753
# Penalties incureed: 271
# Timesteps taken: 754
# Penalties incureed: 271
# Timesteps taken: 755
# Penalties incureed: 271
# Timesteps taken: 756
# Penalties incureed: 271
# Timesteps taken: 757
# Penalties incureed: 271
# Timesteps taken: 758
# Penalties incureed: 271
# Timesteps taken: 759
# Penalties incureed: 271
# Timesteps taken: 760
# Penalties incureed: 271
# Timesteps taken: 761
# Penalties incureed: 271
# Timesteps taken: 762
# Penalties incureed: 271
# Timesteps taken: 763
# Penalties incureed: 271
# Timesteps taken: 764
# Penalties incureed: 271
# Timesteps taken: 765
# Penalties incureed: 271
# Timesteps taken: 766
# Penalties incureed: 271
# Timesteps taken: 767
# Penalties incureed: 271
# Timesteps taken: 768
# Penalties incureed: 271
# Timesteps taken: 769
# Penalties incureed: 271
# Timesteps taken: 770
# Penalties incureed: 272
# Timesteps taken: 771
# Penalties incureed: 273
# Timesteps taken: 772
# Penalties incureed: 274
# Timesteps taken: 773
# Penalties incureed: 274
# Timesteps taken: 774
# Penalties incureed: 274
# Timesteps taken: 775
# Penalties incureed: 274
# Timesteps taken: 776
# Penalties incureed: 275
# Timesteps taken: 777
# Penalties incureed: 275
# Timesteps taken: 778
# Penalties incureed: 276
# Timesteps taken: 779
# Penalties incureed: 276
# Timesteps taken: 780
# Penalties incureed: 276
# Timesteps taken: 781
# Penalties incureed: 276
# Timesteps taken: 782
# Penalties incureed: 276
# Timesteps taken: 783
# Penalties incureed: 277
# Timesteps taken: 784
# Penalties incureed: 278
# Timesteps taken: 785
# Penalties incureed: 279
# Timesteps taken: 786
# Penalties incureed: 280
# Timesteps taken: 787
# Penalties incureed: 281
# Timesteps taken: 788
# Penalties incureed: 281
# Timesteps taken: 789
# Penalties incureed: 281
# Timesteps taken: 790
# Penalties incureed: 281
# Timesteps taken: 791
# Penalties incureed: 282
# Timesteps taken: 792
# Penalties incureed: 282
# Timesteps taken: 793
# Penalties incureed: 283
# Timesteps taken: 794
# Penalties incureed: 283
# Timesteps taken: 795
# Penalties incureed: 284
# Timesteps taken: 796
# Penalties incureed: 285
# Timesteps taken: 797
# Penalties incureed: 285
# Timesteps taken: 798
# Penalties incureed: 285
# Timesteps taken: 799
# Penalties incureed: 285
# Timesteps taken: 800
# Penalties incureed: 285
# Timesteps taken: 801
# Penalties incureed: 285
# Timesteps taken: 802
# Penalties incureed: 286
# Timesteps taken: 803
# Penalties incureed: 286
# Timesteps taken: 804
# Penalties incureed: 287
# Timesteps taken: 805
# Penalties incureed: 287
# Timesteps taken: 806
# Penalties incureed: 288
# Timesteps taken: 807
# Penalties incureed: 288
# Timesteps taken: 808
# Penalties incureed: 289
# Timesteps taken: 809
# Penalties incureed: 290
# Timesteps taken: 810
# Penalties incureed: 291
# Timesteps taken: 811
# Penalties incureed: 291
# Timesteps taken: 812
# Penalties incureed: 291
# Timesteps taken: 813
# Penalties incureed: 292
# Timesteps taken: 814
# Penalties incureed: 292
# Timesteps taken: 815
# Penalties incureed: 292
# Timesteps taken: 816
# Penalties incureed: 292
# Timesteps taken: 817
# Penalties incureed: 293
# Timesteps taken: 818
# Penalties incureed: 293
# Timesteps taken: 819
# Penalties incureed: 294
# Timesteps taken: 820
# Penalties incureed: 294
# Timesteps taken: 821
# Penalties incureed: 294
# Timesteps taken: 822
# Penalties incureed: 294
# Timesteps taken: 823
# Penalties incureed: 294
# Timesteps taken: 824
# Penalties incureed: 294
# Timesteps taken: 825
# Penalties incureed: 295
# Timesteps taken: 826
# Penalties incureed: 296
# Timesteps taken: 827
# Penalties incureed: 297
# Timesteps taken: 828
# Penalties incureed: 298
# Timesteps taken: 829
# Penalties incureed: 298
# Timesteps taken: 830
# Penalties incureed: 298
# Timesteps taken: 831
# Penalties incureed: 298
# Timesteps taken: 832
# Penalties incureed: 298
# Timesteps taken: 833
# Penalties incureed: 298
# Timesteps taken: 834
# Penalties incureed: 298
# Timesteps taken: 835
# Penalties incureed: 298
# Timesteps taken: 836
# Penalties incureed: 298
# Timesteps taken: 837
# Penalties incureed: 298
# Timesteps taken: 838
# Penalties incureed: 298
# Timesteps taken: 839
# Penalties incureed: 299
# Timesteps taken: 840
# Penalties incureed: 300
# Timesteps taken: 841
# Penalties incureed: 300
# Timesteps taken: 842
# Penalties incureed: 301
# Timesteps taken: 843
# Penalties incureed: 301
# Timesteps taken: 844
# Penalties incureed: 301
# Timesteps taken: 845
# Penalties incureed: 301
# Timesteps taken: 846
# Penalties incureed: 301
# Timesteps taken: 847
# Penalties incureed: 302
# Timesteps taken: 848
# Penalties incureed: 302
# Timesteps taken: 849
# Penalties incureed: 302
# Timesteps taken: 850
# Penalties incureed: 302
# Timesteps taken: 851
# Penalties incureed: 302
# Timesteps taken: 852
# Penalties incureed: 302
# Timesteps taken: 853
# Penalties incureed: 302
# Timesteps taken: 854
# Penalties incureed: 302
# Timesteps taken: 855
# Penalties incureed: 302
# Timesteps taken: 856
# Penalties incureed: 302
# Timesteps taken: 857
# Penalties incureed: 302
# Timesteps taken: 858
# Penalties incureed: 302
# Timesteps taken: 859
# Penalties incureed: 302
# Timesteps taken: 860
# Penalties incureed: 302
# Timesteps taken: 861
# Penalties incureed: 302
# Timesteps taken: 862
# Penalties incureed: 303
# Timesteps taken: 863
# Penalties incureed: 303
# Timesteps taken: 864
# Penalties incureed: 303
# Timesteps taken: 865
# Penalties incureed: 304
# Timesteps taken: 866
# Penalties incureed: 304
# Timesteps taken: 867
# Penalties incureed: 304
# Timesteps taken: 868
# Penalties incureed: 304
# Timesteps taken: 869
# Penalties incureed: 305
# Timesteps taken: 870
# Penalties incureed: 306
# Timesteps taken: 871
# Penalties incureed: 307
# Timesteps taken: 872
# Penalties incureed: 307
# Timesteps taken: 873
# Penalties incureed: 308
# Timesteps taken: 874
# Penalties incureed: 308
# Timesteps taken: 875
# Penalties incureed: 308
# Timesteps taken: 876
# Penalties incureed: 308
# Timesteps taken: 877
# Penalties incureed: 309
# Timesteps taken: 878
# Penalties incureed: 310
# Timesteps taken: 879
# Penalties incureed: 311
# Timesteps taken: 880
# Penalties incureed: 312
# Timesteps taken: 881
# Penalties incureed: 313
# Timesteps taken: 882
# Penalties incureed: 313
# Timesteps taken: 883
# Penalties incureed: 314
# Timesteps taken: 884
# Penalties incureed: 314
# Timesteps taken: 885
# Penalties incureed: 315
# Timesteps taken: 886
# Penalties incureed: 315
# Timesteps taken: 887
# Penalties incureed: 315
# Timesteps taken: 888
# Penalties incureed: 316
# Timesteps taken: 889
# Penalties incureed: 317
# Timesteps taken: 890
# Penalties incureed: 317
# Timesteps taken: 891
# Penalties incureed: 317
# Timesteps taken: 892
# Penalties incureed: 318
# Timesteps taken: 893
# Penalties incureed: 319
# Timesteps taken: 894
# Penalties incureed: 319
# Timesteps taken: 895
# Penalties incureed: 319
# Timesteps taken: 896
# Penalties incureed: 320
# Timesteps taken: 897
# Penalties incureed: 320
# Timesteps taken: 898
# Penalties incureed: 320
# Timesteps taken: 899
# Penalties incureed: 320
# Timesteps taken: 900
# Penalties incureed: 320
# Timesteps taken: 901
# Penalties incureed: 321
# Timesteps taken: 902
# Penalties incureed: 322
# Timesteps taken: 903
# Penalties incureed: 322
# Timesteps taken: 904
# Penalties incureed: 322
# Timesteps taken: 905
# Penalties incureed: 323
# Timesteps taken: 906
# Penalties incureed: 323
# Timesteps taken: 907
# Penalties incureed: 323
# Timesteps taken: 908
# Penalties incureed: 323
# Timesteps taken: 909
# Penalties incureed: 324
# Timesteps taken: 910
# Penalties incureed: 324
# Timesteps taken: 911
# Penalties incureed: 324
# Timesteps taken: 912
# Penalties incureed: 324
# Timesteps taken: 913
# Penalties incureed: 324
# Timesteps taken: 914
# Penalties incureed: 324
# Timesteps taken: 915
# Penalties incureed: 324
# Timesteps taken: 916
# Penalties incureed: 325
# Timesteps taken: 917
# Penalties incureed: 325
# Timesteps taken: 918
# Penalties incureed: 325
# Timesteps taken: 919
# Penalties incureed: 325
# Timesteps taken: 920
# Penalties incureed: 325
# Timesteps taken: 921
# Penalties incureed: 325
# Timesteps taken: 922
# Penalties incureed: 325
# Timesteps taken: 923
# Penalties incureed: 325
# Timesteps taken: 924
# Penalties incureed: 325
# Timesteps taken: 925
# Penalties incureed: 325
# Timesteps taken: 926
# Penalties incureed: 326
# Timesteps taken: 927
# Penalties incureed: 327
# Timesteps taken: 928
# Penalties incureed: 328
# Timesteps taken: 929
# Penalties incureed: 329
# Timesteps taken: 930
# Penalties incureed: 329
# Timesteps taken: 931
# Penalties incureed: 330
# Timesteps taken: 932
# Penalties incureed: 330
# Timesteps taken: 933
# Penalties incureed: 330
# Timesteps taken: 934
# Penalties incureed: 330
# Timesteps taken: 935
# Penalties incureed: 330
# Timesteps taken: 936
# Penalties incureed: 331
# Timesteps taken: 937
# Penalties incureed: 331
# Timesteps taken: 938
# Penalties incureed: 332
# Timesteps taken: 939
# Penalties incureed: 332
# Timesteps taken: 940
# Penalties incureed: 333
# Timesteps taken: 941
# Penalties incureed: 333
# Timesteps taken: 942
# Penalties incureed: 333
# Timesteps taken: 943
# Penalties incureed: 334
# Timesteps taken: 944
# Penalties incureed: 334
# Timesteps taken: 945
# Penalties incureed: 335
# Timesteps taken: 946
# Penalties incureed: 335
# Timesteps taken: 947
# Penalties incureed: 336
# Timesteps taken: 948
# Penalties incureed: 336
# Timesteps taken: 949
# Penalties incureed: 337
# Timesteps taken: 950
# Penalties incureed: 337
# Timesteps taken: 951
# Penalties incureed: 337
# Timesteps taken: 952
# Penalties incureed: 337
# Timesteps taken: 953
# Penalties incureed: 338
# Timesteps taken: 954
# Penalties incureed: 339
# Timesteps taken: 955
# Penalties incureed: 339
# Timesteps taken: 956
# Penalties incureed: 340
# Timesteps taken: 957
# Penalties incureed: 340
# Timesteps taken: 958
# Penalties incureed: 340
# Timesteps taken: 959
# Penalties incureed: 340
# Timesteps taken: 960
# Penalties incureed: 340
# Timesteps taken: 961
# Penalties incureed: 341
# Timesteps taken: 962
# Penalties incureed: 341
# Timesteps taken: 963
# Penalties incureed: 341
# Timesteps taken: 964
# Penalties incureed: 341
# Timesteps taken: 965
# Penalties incureed: 341
# Timesteps taken: 966
# Penalties incureed: 341
# Timesteps taken: 967
# Penalties incureed: 341
# Timesteps taken: 968
# Penalties incureed: 341
# Timesteps taken: 969
# Penalties incureed: 342
# Timesteps taken: 970
# Penalties incureed: 342
# Timesteps taken: 971
# Penalties incureed: 343
# Timesteps taken: 972
# Penalties incureed: 343
# Timesteps taken: 973
# Penalties incureed: 344
# Timesteps taken: 974
# Penalties incureed: 344
# Timesteps taken: 975
# Penalties incureed: 344
# Timesteps taken: 976
# Penalties incureed: 344
# Timesteps taken: 977
# Penalties incureed: 345
# Timesteps taken: 978
# Penalties incureed: 345
# Timesteps taken: 979
# Penalties incureed: 346
# Timesteps taken: 980
# Penalties incureed: 347
# Timesteps taken: 981
# Penalties incureed: 347
# Timesteps taken: 982
# Penalties incureed: 347
# Timesteps taken: 983
# Penalties incureed: 347
# Timesteps taken: 984
# Penalties incureed: 348
# Timesteps taken: 985
# Penalties incureed: 348
# Timesteps taken: 986
# Penalties incureed: 348
# Timesteps taken: 987
# Penalties incureed: 348
# Timesteps taken: 988
# Penalties incureed: 348
# Timesteps taken: 989
# Penalties incureed: 348
# Timesteps taken: 990
# Penalties incureed: 348
# Timesteps taken: 991
# Penalties incureed: 349
# Timesteps taken: 992
# Penalties incureed: 349
# Timesteps taken: 993
# Penalties incureed: 350
# Timesteps taken: 994
# Penalties incureed: 350
# Timesteps taken: 995
# Penalties incureed: 350
# Timesteps taken: 996
# Penalties incureed: 350
# Timesteps taken: 997
# Penalties incureed: 350
# Timesteps taken: 998
# Penalties incureed: 350
# Timesteps taken: 999
# Penalties incureed: 350
# Timesteps taken: 1000
# Penalties incureed: 350
# Timesteps taken: 1001
# Penalties incureed: 350
# Timesteps taken: 1002
# Penalties incureed: 350
# Timesteps taken: 1003
# Penalties incureed: 350
# Timesteps taken: 1004
# Penalties incureed: 350
# Timesteps taken: 1005
# Penalties incureed: 350
# Timesteps taken: 1006
# Penalties incureed: 351
# Timesteps taken: 1007
# Penalties incureed: 351
# Timesteps taken: 1008
# Penalties incureed: 351
# Timesteps taken: 1009
# Penalties incureed: 351
# Timesteps taken: 1010
# Penalties incureed: 351
# Timesteps taken: 1011
# Penalties incureed: 351
# Timesteps taken: 1012
# Penalties incureed: 351
# Timesteps taken: 1013
# Penalties incureed: 351
# Timesteps taken: 1014
# Penalties incureed: 351
# Timesteps taken: 1015
# Penalties incureed: 352
# Timesteps taken: 1016
# Penalties incureed: 352
# Timesteps taken: 1017
# Penalties incureed: 353
# Timesteps taken: 1018
# Penalties incureed: 353
# Timesteps taken: 1019
# Penalties incureed: 353
# Timesteps taken: 1020
# Penalties incureed: 353
# Timesteps taken: 1021
# Penalties incureed: 353
# Timesteps taken: 1022
# Penalties incureed: 353
# Timesteps taken: 1023
# Penalties incureed: 353
# Timesteps taken: 1024
# Penalties incureed: 353
# Timesteps taken: 1025
# Penalties incureed: 353
# Timesteps taken: 1026
# Penalties incureed: 353
# Timesteps taken: 1027
# Penalties incureed: 354
# Timesteps taken: 1028
# Penalties incureed: 354
# Timesteps taken: 1029
# Penalties incureed: 354
# Timesteps taken: 1030
# Penalties incureed: 354
# Timesteps taken: 1031
# Penalties incureed: 354
# Timesteps taken: 1032
# Penalties incureed: 354
# Timesteps taken: 1033
# Penalties incureed: 354
# Timesteps taken: 1034
# Penalties incureed: 354
# Timesteps taken: 1035
# Penalties incureed: 354
# Timesteps taken: 1036
# Penalties incureed: 354
# Timesteps taken: 1037
# Penalties incureed: 354
# Timesteps taken: 1038
# Penalties incureed: 354
# Timesteps taken: 1039
# Penalties incureed: 354
# Timesteps taken: 1040
# Penalties incureed: 355
# Timesteps taken: 1041
# Penalties incureed: 355
# Timesteps taken: 1042
# Penalties incureed: 355
# Timesteps taken: 1043
# Penalties incureed: 355
# Timesteps taken: 1044
# Penalties incureed: 355
# Timesteps taken: 1045
# Penalties incureed: 356
# Timesteps taken: 1046
# Penalties incureed: 356
# Timesteps taken: 1047
# Penalties incureed: 357
# Timesteps taken: 1048
# Penalties incureed: 357
# Timesteps taken: 1049
# Penalties incureed: 357
# Timesteps taken: 1050
# Penalties incureed: 357
# Timesteps taken: 1051
# Penalties incureed: 358
# Timesteps taken: 1052
# Penalties incureed: 358
# Timesteps taken: 1053
# Penalties incureed: 358
# Timesteps taken: 1054
# Penalties incureed: 358
# Timesteps taken: 1055
# Penalties incureed: 358
# Timesteps taken: 1056
# Penalties incureed: 358
# Timesteps taken: 1057
# Penalties incureed: 359
# Timesteps taken: 1058
# Penalties incureed: 359
# Timesteps taken: 1059
# Penalties incureed: 359
# Timesteps taken: 1060
# Penalties incureed: 359
# Timesteps taken: 1061
# Penalties incureed: 359
# Timesteps taken: 1062
# Penalties incureed: 359
# Timesteps taken: 1063
# Penalties incureed: 360
# Timesteps taken: 1064
# Penalties incureed: 360
# Timesteps taken: 1065
# Penalties incureed: 360
# Timesteps taken: 1066
# Penalties incureed: 360
# Timesteps taken: 1067
# Penalties incureed: 360
# Timesteps taken: 1068
# Penalties incureed: 360
# Timesteps taken: 1069
# Penalties incureed: 360
# Timesteps taken: 1070
# Penalties incureed: 360
# Timesteps taken: 1071
# Penalties incureed: 360
# Timesteps taken: 1072
# Penalties incureed: 360
# Timesteps taken: 1073
# Penalties incureed: 360
# Timesteps taken: 1074
# ...
# Penalties incureed: 450
# Timesteps taken: 1391
# Penalties incureed: 451
# Timesteps taken: 1392
# Penalties incureed: 452
# Timesteps taken: 1393
# Penalties incureed: 452
# Timesteps taken: 1394
# Penalties incureed: 453
# Timesteps taken: 1395
# Penalties incureed: 453
# Timesteps taken: 1396
# Penalties incureed: 453
# Timesteps taken: 1397
# Penalties incureed: 454
# Timesteps taken: 1398
# Penalties incureed: 454
# Timesteps taken: 1399
# Penalties incureed: 454
# Timesteps taken: 1400
# Penalties incureed: 454
# Timesteps taken: 1401
# Penalties incureed: 454
# Timesteps taken: 1402
# Penalties incureed: 454
# Timesteps taken: 1403
# Penalties incureed: 455
# Timesteps taken: 1404
# Penalties incureed: 456
# Timesteps taken: 1405
# Penalties incureed: 456
# Timesteps taken: 1406
# Penalties incureed: 456
# Timesteps taken: 1407
# Penalties incureed: 456
# Timesteps taken: 1408
# Penalties incureed: 456
# Timesteps taken: 1409
# Penalties incureed: 456
# Timesteps taken: 1410
# Penalties incureed: 456
# Timesteps taken: 1411
# Penalties incureed: 456
# Timesteps taken: 1412
# Penalties incureed: 457
# Timesteps taken: 1413
# Penalties incureed: 457
# Timesteps taken: 1414
# Penalties incureed: 458
# Timesteps taken: 1415
# Penalties incureed: 458
# Timesteps taken: 1416
# Penalties incureed: 459
# Timesteps taken: 1417
# Penalties incureed: 459
# Timesteps taken: 1418
# Penalties incureed: 459
# Timesteps taken: 1419
# Penalties incureed: 460
# Timesteps taken: 1420
# Penalties incureed: 461
# Timesteps taken: 1421
# Penalties incureed: 461
# Timesteps taken: 1422
# Penalties incureed: 462
# Timesteps taken: 1423
# Penalties incureed: 462
# Timesteps taken: 1424
# Penalties incureed: 463
# Timesteps taken: 1425
# Penalties incureed: 463
# Timesteps taken: 1426
# Penalties incureed: 463
# Timesteps taken: 1427
# Penalties incureed: 463
# Timesteps taken: 1428
# Penalties incureed: 463
# Timesteps taken: 1429
# Penalties incureed: 463
# Timesteps taken: 1430
# Penalties incureed: 463
# Timesteps taken: 1431
# Penalties incureed: 463
# Timesteps taken: 1432
# Penalties incureed: 463
# Timesteps taken: 1433
# Penalties incureed: 463
# Timesteps taken: 1434
# Penalties incureed: 464
# Timesteps taken: 1435
# Penalties incureed: 465
# Timesteps taken: 1436
# Penalties incureed: 466
# Timesteps taken: 1437
# Penalties incureed: 466
# Timesteps taken: 1438
# Penalties incureed: 466
# Timesteps taken: 1439
# Penalties incureed: 467
# Timesteps taken: 1440
# Penalties incureed: 467
# Timesteps taken: 1441
# Penalties incureed: 467
# Timesteps taken: 1442
# Penalties incureed: 468
# Timesteps taken: 1443
# Penalties incureed: 468
# Timesteps taken: 1444
# Penalties incureed: 469
# Timesteps taken: 1445
# Penalties incureed: 469
# Timesteps taken: 1446
# Penalties incureed: 470
# Timesteps taken: 1447
# Penalties incureed: 470
# Timesteps taken: 1448
# Penalties incureed: 470
# Timesteps taken: 1449
# Penalties incureed: 471
# Timesteps taken: 1450
# Penalties incureed: 472
# Timesteps taken: 1451
# Penalties incureed: 472
# Timesteps taken: 1452
# Penalties incureed: 473
# Timesteps taken: 1453
# Penalties incureed: 473
# Timesteps taken: 1454
# Penalties incureed: 473
# Timesteps taken: 1455
# Penalties incureed: 474
# Timesteps taken: 1456
# Penalties incureed: 475
# Timesteps taken: 1457
# Penalties incureed: 475
# Timesteps taken: 1458
# Penalties incureed: 475
# Timesteps taken: 1459
# Penalties incureed: 476
# Timesteps taken: 1460
# Penalties incureed: 476
# Timesteps taken: 1461
# Penalties incureed: 476
# Timesteps taken: 1462
# Penalties incureed: 476
# Timesteps taken: 1463
# Penalties incureed: 476
# Timesteps taken: 1464
# Penalties incureed: 476
# Timesteps taken: 1465
# Penalties incureed: 476
# Timesteps taken: 1466
# Penalties incureed: 476
# Timesteps taken: 1467
# Penalties incureed: 476
# Timesteps taken: 1468
# Penalties incureed: 477
# Timesteps taken: 1469
# Penalties incureed: 477
# Timesteps taken: 1470
# Penalties incureed: 477
# Timesteps taken: 1471
# Penalties incureed: 477
# Timesteps taken: 1472
# Penalties incureed: 477
# Timesteps taken: 1473
# Penalties incureed: 478
# Timesteps taken: 1474
# Penalties incureed: 478
# Timesteps taken: 1475
# Penalties incureed: 478
# Timesteps taken: 1476
# Penalties incureed: 479
# Timesteps taken: 1477
# Penalties incureed: 479
# Timesteps taken: 1478
# Penalties incureed: 479
# Timesteps taken: 1479
# Penalties incureed: 479
# Timesteps taken: 1480
# Penalties incureed: 479
# Timesteps taken: 1481
# Penalties incureed: 479
# Timesteps taken: 1482
# Penalties incureed: 480
# Timesteps taken: 1483
# Penalties incureed: 480
# Timesteps taken: 1484
# Penalties incureed: 480
# Timesteps taken: 1485
# Penalties incureed: 481
# Timesteps taken: 1486
# Penalties incureed: 481
# Timesteps taken: 1487
# Penalties incureed: 482
# Timesteps taken: 1488
# Penalties incureed: 482
# Timesteps taken: 1489
# Penalties incureed: 482
# Timesteps taken: 1490
# Penalties incureed: 483
# Timesteps taken: 1491
# Penalties incureed: 483
# Timesteps taken: 1492
# Penalties incureed: 483
# Timesteps taken: 1493
# Penalties incureed: 483
# Timesteps taken: 1494
# Penalties incureed: 483
# Timesteps taken: 1495
# Penalties incureed: 483
# Timesteps taken: 1496
# Penalties incureed: 484
# Timesteps taken: 1497
# Penalties incureed: 485
# Timesteps taken: 1498
# Penalties incureed: 485
# Timesteps taken: 1499
# Penalties incureed: 485
# Timesteps taken: 1500
# Penalties incureed: 485
# Timesteps taken: 1501
# Penalties incureed: 485
# Timesteps taken: 1502
# Penalties incureed: 485
# Timesteps taken: 1503
# Penalties incureed: 485
# Timesteps taken: 1504
# Penalties incureed: 485
# Timesteps taken: 1505
# Penalties incureed: 485
# Timesteps taken: 1506
# Penalties incureed: 486
# Timesteps taken: 1507
# Penalties incureed: 487
# Timesteps taken: 1508
# Penalties incureed: 487
# Timesteps taken: 1509
# Penalties incureed: 487
# Timesteps taken: 1510
# Penalties incureed: 487
# Timesteps taken: 1511
# Penalties incureed: 487
# Timesteps taken: 1512
# Penalties incureed: 487
# Timesteps taken: 1513
# Penalties incureed: 487
# Timesteps taken: 1514
# Penalties incureed: 488
# Timesteps taken: 1515
# Penalties incureed: 488
# Timesteps taken: 1516
# Penalties incureed: 488
# Timesteps taken: 1517
# Penalties incureed: 488
# Timesteps taken: 1518
# Penalties incureed: 488
# Timesteps taken: 1519
# Penalties incureed: 489
# Timesteps taken: 1520
# Penalties incureed: 490
# Timesteps taken: 1521
# Penalties incureed: 490
# Timesteps taken: 1522
# Penalties incureed: 491
# Timesteps taken: 1523
# Penalties incureed: 491
# Timesteps taken: 1524
# Penalties incureed: 492
# Timesteps taken: 1525
# Penalties incureed: 492
# Timesteps taken: 1526
# Penalties incureed: 492
# Timesteps taken: 1527
# Penalties incureed: 492
# Timesteps taken: 1528
# Penalties incureed: 492
# Timesteps taken: 1529
# Penalties incureed: 492
# Timesteps taken: 1530
# Penalties incureed: 493
# Timesteps taken: 1531
# Penalties incureed: 493
# Timesteps taken: 1532
# Penalties incureed: 493
# Timesteps taken: 1533
# Penalties incureed: 493
# Timesteps taken: 1534
# Penalties incureed: 494
# Timesteps taken: 1535
# Penalties incureed: 495
# Timesteps taken: 1536
# Penalties incureed: 495
# Timesteps taken: 1537
# Penalties incureed: 495
# Timesteps taken: 1538
# Penalties incureed: 496
# Timesteps taken: 1539
# Penalties incureed: 496
# Timesteps taken: 1540
# Penalties incureed: 497
# Timesteps taken: 1541
# Penalties incureed: 498
# Timesteps taken: 1542
# Penalties incureed: 498
# Timesteps taken: 1543
# Penalties incureed: 499
# Timesteps taken: 1544
# Penalties incureed: 499
# Timesteps taken: 1545
# Penalties incureed: 499
# Timesteps taken: 1546
# Penalties incureed: 499
# Timesteps taken: 1547
# Penalties incureed: 499
# Timesteps taken: 1548
# Penalties incureed: 499
# Timesteps taken: 1549
# Penalties incureed: 500
# Timesteps taken: 1550
# Penalties incureed: 501
# Timesteps taken: 1551
# Penalties incureed: 501
# Timesteps taken: 1552
# Penalties incureed: 501
# Timesteps taken: 1553
# Penalties incureed: 501
# Timesteps taken: 1554
# Penalties incureed: 501
# Timesteps taken: 1555
# Penalties incureed: 502
# Timesteps taken: 1556
# Penalties incureed: 502
# Timesteps taken: 1557
# Penalties incureed: 502
# Timesteps taken: 1558
# Penalties incureed: 503
# Timesteps taken: 1559
# Penalties incureed: 503
# Timesteps taken: 1560
# Penalties incureed: 503
# Timesteps taken: 1561
# Penalties incureed: 504
# Timesteps taken: 1562
# Penalties incureed: 504
# Timesteps taken: 1563
# Penalties incureed: 504
# Timesteps taken: 1564
# Penalties incureed: 504
# Timesteps taken: 1565
# Penalties incureed: 504
# Timesteps taken: 1566
# Penalties incureed: 504
# Timesteps taken: 1567
# Penalties incureed: 504
# Timesteps taken: 1568
# Penalties incureed: 504
# Timesteps taken: 1569
# Penalties incureed: 504
# Timesteps taken: 1570
# Penalties incureed: 504
# Timesteps taken: 1571
# Penalties incureed: 504
# Timesteps taken: 1572
# Penalties incureed: 504
# Timesteps taken: 1573
# Penalties incureed: 504
# Timesteps taken: 1574
# Penalties incureed: 504
# Timesteps taken: 1575
# Penalties incureed: 504
# Timesteps taken: 1576
# Penalties incureed: 504
# Timesteps taken: 1577
# Penalties incureed: 504
# Timesteps taken: 1578
# Penalties incureed: 505
# Timesteps taken: 1579
# Penalties incureed: 506
# Timesteps taken: 1580
# Penalties incureed: 506
# Timesteps taken: 1581
# Penalties incureed: 506
# Timesteps taken: 1582
# Penalties incureed: 506
# Timesteps taken: 1583
# Penalties incureed: 506
# Timesteps taken: 1584
# Penalties incureed: 507
# Timesteps taken: 1585
# Penalties incureed: 508
# Timesteps taken: 1586
# Penalties incureed: 508
# Timesteps taken: 1587
# Penalties incureed: 508
# Timesteps taken: 1588
# Penalties incureed: 508
# Timesteps taken: 1589
# Penalties incureed: 508
# Timesteps taken: 1590
# Penalties incureed: 508
# Timesteps taken: 1591
# Penalties incureed: 509
# Timesteps taken: 1592
# Penalties incureed: 509
# Timesteps taken: 1593
# Penalties incureed: 510
# Timesteps taken: 1594
# Penalties incureed: 510
# Timesteps taken: 1595
# Penalties incureed: 510
# Timesteps taken: 1596
# Penalties incureed: 510
# Timesteps taken: 1597
# Penalties incureed: 510
# Timesteps taken: 1598
# Penalties incureed: 510
# Timesteps taken: 1599
# Penalties incureed: 510
# Timesteps taken: 1600
# Penalties incureed: 510
# Timesteps taken: 1601
# Penalties incureed: 510
# Timesteps taken: 1602
# Penalties incureed: 511
# Timesteps taken: 1603
# Penalties incureed: 512
# Timesteps taken: 1604
# Penalties incureed: 512
# Timesteps taken: 1605
# Penalties incureed: 512
# Timesteps taken: 1606
# Penalties incureed: 512
# Timesteps taken: 1607
# Penalties incureed: 513
# Timesteps taken: 1608
# Penalties incureed: 513
# Timesteps taken: 1609
# Penalties incureed: 514
# Timesteps taken: 1610
# Penalties incureed: 515
# Timesteps taken: 1611
# Penalties incureed: 515
# Timesteps taken: 1612
# Penalties incureed: 516
# Timesteps taken: 1613
# Penalties incureed: 517
# Timesteps taken: 1614
# Penalties incureed: 518
# Timesteps taken: 1615
# Penalties incureed: 519
# Timesteps taken: 1616
# Penalties incureed: 520
# Timesteps taken: 1617
# Penalties incureed: 520
# Timesteps taken: 1618
# Penalties incureed: 521
# Timesteps taken: 1619
# Penalties incureed: 521
# Timesteps taken: 1620
# Penalties incureed: 521
# Timesteps taken: 1621
# Penalties incureed: 521
# Timesteps taken: 1622
# Penalties incureed: 521
# Timesteps taken: 1623
# Penalties incureed: 521
# Timesteps taken: 1624
# Penalties incureed: 522
# Timesteps taken: 1625
# Penalties incureed: 522
# Timesteps taken: 1626
# Penalties incureed: 522
# Timesteps taken: 1627
# Penalties incureed: 523
# Timesteps taken: 1628
# Penalties incureed: 523
# Timesteps taken: 1629
# Penalties incureed: 523
# Timesteps taken: 1630
# Penalties incureed: 524
# Timesteps taken: 1631
# Penalties incureed: 524
# Timesteps taken: 1632
# Penalties incureed: 525
# Timesteps taken: 1633
# Penalties incureed: 525
# Timesteps taken: 1634
# Penalties incureed: 526
# Timesteps taken: 1635
# Penalties incureed: 526
# Timesteps taken: 1636
# Penalties incureed: 526
# Timesteps taken: 1637
# Penalties incureed: 527
# Timesteps taken: 1638
# Penalties incureed: 527
# Timesteps taken: 1639
# Penalties incureed: 527
# Timesteps taken: 1640
# Penalties incureed: 527
# Timesteps taken: 1641
# Penalties incureed: 527
# Timesteps taken: 1642
# Penalties incureed: 527
# Timesteps taken: 1643
# Penalties incureed: 527
# Timesteps taken: 1644
# Penalties incureed: 527
# Timesteps taken: 1645
# Penalties incureed: 528
# Timesteps taken: 1646
# Penalties incureed: 529
# Timesteps taken: 1647
# Penalties incureed: 530
# Timesteps taken: 1648
# Penalties incureed: 530
# Timesteps taken: 1649
# Penalties incureed: 531
# Timesteps taken: 1650
# Penalties incureed: 531
# Timesteps taken: 1651
# Penalties incureed: 531
# Timesteps taken: 1652
# Penalties incureed: 531
# Timesteps taken: 1653
# Penalties incureed: 531
# Timesteps taken: 1654
# Penalties incureed: 531
# Timesteps taken: 1655
# Penalties incureed: 532
# Timesteps taken: 1656
# Penalties incureed: 532
# Timesteps taken: 1657
# Penalties incureed: 533
# Timesteps taken: 1658
# Penalties incureed: 533
# Timesteps taken: 1659
# Penalties incureed: 533
# Timesteps taken: 1660
# Penalties incureed: 533
# Timesteps taken: 1661
# Penalties incureed: 533
# Timesteps taken: 1662
# Penalties incureed: 533
# Timesteps taken: 1663
# Penalties incureed: 533
# Timesteps taken: 1664
# Penalties incureed: 533
# Timesteps taken: 1665
# Penalties incureed: 533
# Timesteps taken: 1666
# Penalties incureed: 534
# Timesteps taken: 1667
# Penalties incureed: 534
# Timesteps taken: 1668
# Penalties incureed: 534
# Timesteps taken: 1669
# Penalties incureed: 534
# Timesteps taken: 1670
# Penalties incureed: 535
# Timesteps taken: 1671
# Penalties incureed: 536
# Timesteps taken: 1672
# Penalties incureed: 536
# Timesteps taken: 1673
# Penalties incureed: 537
# Timesteps taken: 1674
# Penalties incureed: 538
# Timesteps taken: 1675
# Penalties incureed: 538
# Timesteps taken: 1676
# Penalties incureed: 538
# Timesteps taken: 1677
# Penalties incureed: 539
# Timesteps taken: 1678
# Penalties incureed: 540
# Timesteps taken: 1679
# Penalties incureed: 540
# Timesteps taken: 1680
# Penalties incureed: 540
# Timesteps taken: 1681
# Penalties incureed: 541
# Timesteps taken: 1682
# Penalties incureed: 541
# Timesteps taken: 1683
# Penalties incureed: 541
# Timesteps taken: 1684
# Penalties incureed: 541
# Timesteps taken: 1685
# Penalties incureed: 541
# Timesteps taken: 1686
# Penalties incureed: 541
# Timesteps taken: 1687
# Penalties incureed: 541
# Timesteps taken: 1688
# Penalties incureed: 541
# Timesteps taken: 1689
# Penalties incureed: 541
# Timesteps taken: 1690
# Penalties incureed: 541
# Timesteps taken: 1691
# Penalties incureed: 541
# Timesteps taken: 1692
# Penalties incureed: 541
# Timesteps taken: 1693
# Penalties incureed: 541
# Timesteps taken: 1694
# Penalties incureed: 541
# Timesteps taken: 1695
# Penalties incureed: 541
# Timesteps taken: 1696
# Penalties incureed: 542
# Timesteps taken: 1697
# Penalties incureed: 543
# Timesteps taken: 1698
# Penalties incureed: 543
# Timesteps taken: 1699
# Penalties incureed: 544
# Timesteps taken: 1700
# Penalties incureed: 544
# Timesteps taken: 1701
# Penalties incureed: 545
# Timesteps taken: 1702
# Penalties incureed: 545
# Timesteps taken: 1703
# Penalties incureed: 545
# Timesteps taken: 1704
# Penalties incureed: 545
# Timesteps taken: 1705
# Penalties incureed: 545
# Timesteps taken: 1706
# Penalties incureed: 545
# Timesteps taken: 1707
# Penalties incureed: 545
# Timesteps taken: 1708
# Penalties incureed: 546
# Timesteps taken: 1709
# Penalties incureed: 546
# Timesteps taken: 1710
# Penalties incureed: 547
# Timesteps taken: 1711
# Penalties incureed: 547
# Timesteps taken: 1712
# Penalties incureed: 547
# Timesteps taken: 1713
# Penalties incureed: 547
# Timesteps taken: 1714
# Penalties incureed: 547
# Timesteps taken: 1715
# Penalties incureed: 547
# Timesteps taken: 1716
# Penalties incureed: 547
# Timesteps taken: 1717
# Penalties incureed: 547
# Timesteps taken: 1718
# Penalties incureed: 547
# Timesteps taken: 1719
# Penalties incureed: 547
# Timesteps taken: 1720
# Penalties incureed: 548
# Timesteps taken: 1721
# Penalties incureed: 549
# Timesteps taken: 1722
# Penalties incureed: 549
# Timesteps taken: 1723
# Penalties incureed: 549
# Timesteps taken: 1724
# Penalties incureed: 549
# Timesteps taken: 1725
# Penalties incureed: 550
# Timesteps taken: 1726
# Penalties incureed: 551
# Timesteps taken: 1727
# Penalties incureed: 551
# Timesteps taken: 1728
# Penalties incureed: 552
# Timesteps taken: 1729
# Penalties incureed: 552
# Timesteps taken: 1730
# Penalties incureed: 553
# Timesteps taken: 1731
# Penalties incureed: 554
# Timesteps taken: 1732
# Penalties incureed: 555
# Timesteps taken: 1733
# Penalties incureed: 555
# Timesteps taken: 1734
# Penalties incureed: 555
# Timesteps taken: 1735
# Penalties incureed: 555
# Timesteps taken: 1736
# Penalties incureed: 555
# Timesteps taken: 1737
# Penalties incureed: 555

# %%
from IPython.display import clear_output
from time import sleep

def print_frames(frames):
  for i, frame in enumerate(frames):
    clear_output(wait=True)
    print(frame['frame'])
    print(f"Timestep: {i + 1}")
    print(f"State: {frame['state']}")
    print(f"Action: {frame['action']}")
    print(f"Reward: {frame['reward']}")
    sleep(.1)
print_frames(frames)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
#
# Timestep: 1737
# State: 410
# Action: 5
# Reward: 20

# %%
import numpy as np
q_table = np.zeros([env.observation_space.n, env.action_space.n])

# %%
# %%time
 import random
 from IPython.display import clear_output

 alpha = 0.1
 gamma = 0.6
 epilson = 0.1

 all_epochs = []
 all_penalties = []

 for i in range(1, 100001):
   state = env.reset()

   epochs, penalties, reward, = 0, 1, 0

   done = False
   while not done:
        if random.uniform(0, 1) < epilson:
           action = env.action_space.sample()
        else:
           action = np.argmax(q_table[state])

        next_state, reward, done, info = env.step(action)
        old_value = q_table[state, action]
        next_max = np.max(q_table[next_state])
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state, action] = new_value
        if reward == -10:
         penalties += 1

        state = next_state
        epochs += 1

   if i % 100 == 0:
        clear_output(wait=True)
        print(f"Episode: {i}")

print("Training finshed.\n")
# Out:
# Episode: 100000
# Training finshed.
#
# CPU times: user 1min 7s, sys: 9 s, total: 1min 16s
# Wall time: 1min 16s

# %%
q_table[328]
# Out:
# array([ -2.40962607,  -2.27325184,  -2.39948909,  -2.35646405,
#        -10.81331639, -10.80269833])

# %%
total_epochs, total_penalties = 1, 1
episodes = 100

for _ in range(episodes):
  state = env.reset()
  epochs, penalties, reward = 0, 1, 0

  done = False

  while not done:
    action = np.argmax(q_table[state])
    state, reward, done, info = env.step(action)

    if reward == -10:
      penalties += 1

      epochs +=1

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / episodes}")
print(f"Average penalties per episodes: {total_penalties/ episodes}")
# Out:
# Results after 100 episodes:
# Average timesteps per episode: 0.01
# Average penalties per episodes: 13.26

# %%
env.reset()
prev_screen = env.render(mode='rgb_array')
plt.imshow(prev_screen)

for _ in range(episodes):
  action = env.action_space.sample()
  state, penalty, done, info = env.step(action)
  screen = env.render(mode='rgb_array')

  plt.imshow(screen)
  ipythondisplay.clear_output(wait=True)
  ipythondisplay.display(plt.gcf())

  if done:
    break

ipythondisplay.clear_output(wait=True)
env.close()

ipythondisplay.clear_output(wait=True)
env.close()
